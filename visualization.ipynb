# %%
import pandas as pd
import os
from tqdm import tqdm
import logging

logger = logging.getLogger(__name__)
logging.basicConfig(level=logging.INFO)

def read_json(path = "data_preprocessed_03"):
    for __json in tqdm(os.listdir(path)):
        logger.info(f"Reading file: {__json}")
        df = pd.read_json("data/"+__json)
        print(df)
        break

read_json()
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]INFO:__main__:Reading file: file-age=10.json
#   0%|          | 0/16 [00:00<?, ?it/s]
#                                                  slug  \
# 0        kaufmannischer-mitarbeiter-hofgeismar-154258
# 1   personalreferenten-mit-schwerpunkt-personaladm...
# 2     innenarchitekt-interior-design-regensburg-99438
# 3                            controller-hamburg-64415
# 4                      teamassistenz-frankfurt-110156
# ..                                                ...
# 95  fundraising-specialistin-all-genders-are-welco...
# 96  referentin-der-geschaftsfuhrung-all-genders-ar...
# 97  e-commerce-manager-online-marketing-manager-ne...
# 98  werkstudentin-fur-data-analytics-web-analytics...
# 99                        hr-allrounder-munich-486097
#
#                      company_name  \
# 0   Nexus Personalmanagement GmbH
# 1                         Celenus
# 2                  Ladenbau Hanke
# 3                        TCC GmbH
# 4        LORENZ Orga-Systeme GmbH
# ..                            ...
# 95                      socialbee
# 96                      socialbee
# 97                     TRULO GmbH
# 98                    recyclehero
# 99                           GPNZ
#
#                                                 title  \
# 0                 Kaufmännische:r Mitarbeiter (m/w/w)
# 1   Personalreferenten (m/w/d) mit Schwerpunkt Per...
# 2            Innenarchitekt / Interior Design (m/w/d)
# 3                                  Controller (m/w/d)
# 4                               Teamassistenz (M/W/D)
# ..                                                ...
# 95  Fundraising Specialist*in (all genders are wel...
# 96  Referent*in der Geschäftsführung (all genders ...
# 97      E-Commerce Manager / Online Marketing Manager
# 98  Werkstudent*in (m/w/d) für Data Analytics / We...
# 99                              HR Allrounder (m/w/d)
#
#                                           description  remote  \
# 0   <p>Als inhabergeführtes Unternehmen verstehen ...   False
# 1   <p>Celenus salvea ist in Deutschland einer der...   False
# 2   <p>Wir sind Hersteller von hochwertigen Ladene...   False
# 3   <p>Prof. Dr. Christian Storm und David Barg ke...   False
# 4   <p>LORENZ Orga-Systeme GmbH ist ein Software-E...   False
# ..                                                ...     ...
# 95  <h2>UNSERE MISSION</h2>\n<p>Wir sind eines der...    True
# 96  <h2>UNSERE MISSION</h2>\n<p>Wir sind eines der...    True
# 97  <p><strong>Möchtest du Teil einer der am schne...   False
# 98  <p>Hast du Lust, ein Impact Start-up Data Geni...   False
# 99  <p>Die GPNZ – Gesellschaft für Praxisnachfolge...   False
#
#                                                   url  \
# 0   https://www.arbeitnow.com/jobs/companies/nexus...
# 1   https://www.arbeitnow.com/jobs/companies/celen...
# 2   https://www.arbeitnow.com/jobs/companies/laden...
# 3   https://www.arbeitnow.com/jobs/companies/tcc-g...
# 4   https://www.arbeitnow.com/jobs/companies/loren...
# ..                                                ...
# 95  https://www.arbeitnow.com/jobs/companies/socia...
# 96  https://www.arbeitnow.com/jobs/companies/socia...
# 97  https://www.arbeitnow.com/jobs/companies/trulo...
# 98  https://www.arbeitnow.com/jobs/companies/recyc...
# 99  https://www.arbeitnow.com/jobs/companies/gpnz/...
#
#                                      tags          job_types    location  \
# 0        [Administration and Secretariat]   [berufseinstieg]  Hofgeismar
# 1                                    [HR]   [berufserfahren]   Offenburg
# 2                       [Interior Design]                 []  Regensburg
# 3                               [Finance]                 []     Hamburg
# 4                  [Software Development]                 []   Frankfurt
# ..                                    ...                ...         ...
# 95  [Remote, Marketing and Communication]   [berufseinstieg]      Munich
# 96  [Remote, Marketing and Communication]   [berufseinstieg]      Munich
# 97          [Marketing and Communication]                 []       Neuss
# 98                                   [IT]  [Working student]     Hamburg
# 99                                   [HR]                 []      Munich
#
#             created_at
# 0  2023-12-14 11:49:02
# 1  2023-12-14 11:49:02
# 2  2023-12-14 11:49:02
# 3  2023-12-14 11:49:02
# 4  2023-12-14 11:49:02
# ..                 ...
# 95 2023-12-13 17:49:03
# 96 2023-12-13 17:49:03
# 97 2023-12-13 17:49:03
# 98 2023-12-13 17:49:03
# 99 2023-12-13 17:49:03
#
# [100 rows x 10 columns]
